# %%
def vectorfield(w, t, p):
    """
    Defines the differential equations for the coupled spring-mass system.

    Arguments:
        w :  vector of the state variables:
                  w = [x1,y1,x2,y2]
        t :  time
        p :  vector of the parameters:
                  p = [m1,m2,k1,k2,L1,L2,b1,b2]
    """
    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2, mu1, mu2 = p

    # Create f = (x1',y1',x2',y2'):
    f = [y1,
         (-b1 * y1 - k1 * (x1) + k2 * (x2 - x1)+ mu1*((x1)**3)+ mu2*((x1-x2)**3)) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1)+ mu2*((x2-x1)**3)) / m2]
    return f

# %%
# Use ODEINT to solve the differential equations defined by the vector field
from scipy.integrate import odeint

# Parameter values
# Masses:
m1 = 1.0
m2 = 1.0
# Spring constants
k1 = 0.4
k2 = 1.808
# Natural lengths
L1 = 0.0
L2 = 0.0
# Friction coefficients
b1 = 0.0
b2 = 0.0
#Non-linear coefficients
u1=-1.0/6.0
u2=-1.0/10.0

# Initial conditions
# x1 and x2 are the initial displacements; y1 and y2 are the initial velocities
x1 = 1.0
y1 = 0.0
x2 = -0.5
y2 = 0.0

# ODE solver parameters
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 50.0
numpoints = 500

# Create the time samples for the output of the ODE solver.
# I use a large number of points, only because I want to make
# a plot of the solution that looks nice.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
p = [m1, m2, k1, k2, L1, L2, b1, b2,u1,u2]
w0 = [x1, y1, x2, y2]

# Call the ODE solver.
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('Ejemplo3_1.dat', 'w') as f:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3], file=f)

# %%
# Plot the solution that was generated

import numpy
import matplotlib.pyplot as plt
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo3_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x1')
ylabel('v')
grid(True)
#hold(True)
lw = 1.5

plt.xlim(-2,2)
plt.ylim(-2,2)

plot(x1,y1, 'r', linewidth=lw)
        
title('Phase plot for x1')
savefig('Ejemplo3_1.1.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo3_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x2')
ylabel('v')
grid(True)
#hold(True)
lw = 1

plt.xlim(-2,2)
plt.ylim(-2,2)

plot(x2,y2, 'y', linewidth=lw)
                                    
#legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Phase plot for x2')
savefig('Ejemplo3_1.2.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo3_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x1')
grid(True)
lw = 1
plt.xlim(0,50)
plt.ylim(-2,2)

plot(t,x1, 'b', linewidth=lw)
                                    
title('Plot of x1')
savefig('Ejemplo3_1.3.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo3_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x2')
grid(True)

lw = 1
plt.xlim(0,50)
plt.ylim(-2,2)

plot(t,x2, 'r', linewidth=lw)
                                    
title('Plot of x2')
savefig('Ejemplo3_1.4.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo3_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x')
grid(True)

lw = 1
plt.xlim(0,50)
plt.ylim(-2,2)

plot(t,x2, 'b', linewidth=lw)
plot(t,x1, 'g', linewidth=lw)
                                    
title('Plot of x1 and x2')
savefig('Ejemplo3_1.5.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo3_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x1')
ylabel('x2')
grid(True)

lw = 1
plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)

plot(x1,x2, 'm', linewidth=lw)

title('Plot of x1 versus x2')
savefig('Ejemplo3_1.6.png', dpi=100)

# %%
def vectorfield(w, t, p):
    """
    Defines the differential equations for the coupled spring-mass system.

    Arguments:
        w :  vector of the state variables:
                  w = [x1,y1,x2,y2]
        t :  time
        p :  vector of the parameters:
                  p = [m1,m2,k1,k2,L1,L2,b1,b2]
    """
    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2, mu1, mu2 = p

    # Create f = (x1',y1',x2',y2'):
    f = [y1,
         (-b1 * y1 - k1 * (x1) + k2 * (x2 - x1)+ mu1*((x1)**3)+ mu2*((x1-x2)**3)) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1)+ mu2*((x2-x1)**3)) / m2]
    return f

# %%
# Use ODEINT to solve the differential equations defined by the vector field
from scipy.integrate import odeint
import numpy as np

# Parameter values
# Masses:
m1 = 1.0
m2 = 1.0
# Spring constants
k1 = 0.4
k2 = 1.808
# Natural lengths
L1 = 0.0
L2 = 0.0
# Friction coefficients
b1 = 0.0
b2 = 0.0

#Non-linear coefficients
mu1=-1.0/6.0
mu2=-1.0/10.0

# Initial conditions
# x1 and x2 are the initial displacements; y1 and y2 are the initial velocities
x1 = -0.5
y1 = 1.0/2.0
x2 = 3.001
y2 = 5.9

# ODE solver parameters
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 50
numpoints = 500

# Create the time samples for the output of the ODE solver.
# I use a large number of points, only because I want to make
# a plot of the solution that looks nice.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
p = [m1, m2, k1, k2, L1, L2, b1, b2, mu1, mu2]
w0 = [x1, y1, x2, y2]

# Call the ODE solver.
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('Ejemplo3_2.dat', 'w') as f: # Print & save the solution. 
    for t1, w1 in zip(t, wsol): print(t1, w1[0], w1[1], w1[2], w1[3], file=f)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
from matplotlib import pyplot as pl
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('Ejemplo3_2.dat', unpack=True)


figure(1, figsize=(6, 4.5))
lw=1
plot(x1,xy, 'b', linewidth=lw)
title("Phase plot para $X_1$")
grid(True)
savefig("nonlinearsprings3.2.1.png", dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo3_2.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x2')
ylabel('v')
grid(True)
#hold(True)
lw = 1

plt.xlim(-10,10)
plt.ylim(-10,10)

plot(x2,y2, 'r', linewidth=lw)
                                    
#legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Phase plot for x2')
savefig('Ejemplo3_2.2.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo3_2.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x1')
ylabel('x2')
grid(True)
#hold(True)
lw = 1
plt.xlim(-10,10)
plt.ylim(-10,10)

plot(x1,x2, 'y', linewidth=lw)
                                    
#legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Plot of x1 versus x2')
savefig('Ejemplo3_2.3.png', dpi=100)

# %%
def vectorfield(w, t, p):
    """
    Defines the differential equations for the coupled spring-mass system.

    Arguments:
        w :  vector of the state variables:
                  w = [x1,y1,x2,y2]
        t :  time
        p :  vector of the parameters:
                  p = [m1,m2,k1,k2,L1,L2,b1,b2]
    """
    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2,u1,u2 = p

    # Create f = (x1',y1',x2',y2'):
    f = [y1,
         (-b1 * y1 - k1 * (x1 - L1)+ u1 * ((x1 - L1)**3) - k2 * (x1 - L2-x2)+ u2 *  (x1 - L2-x2)**3) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1 - L2) + u2 * (x2 - x1 - L2)**3 ) / m2]
    return f

# %%
# Use ODEINT to solve the differential equations defined by the vector field
from scipy.integrate import odeint

# Parameter values
# Masses:
m1 = 1.0
m2 = 1.0
# Spring constants
k1 = 0.4
k2 = 1.808
# Natural lengths
L1 = 0.0
L2 = 0.0
# Friction coefficients
b1 = 0.0
b2 = 0.0
#Non-linear coefficients
u1=-1.0/6.0
u2=-1.0/10.0

# Initial conditions
# x1 and x2 are the initial displacements; y1 and y2 are the initial velocities
x1 = -0.6
y1 = 1/2
x2 = 3.001
y2 = 5.9

# ODE solver parameters
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 200.0
numpoints = 1000

# Create the time samples for the output of the ODE solver.
# I use a large number of points, only because I want to make
# a plot of the solution that looks nice.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
p = [m1, m2, k1, k2, L1, L2, b1, b2,u1,u2]
w0 = [x1, y1, x2, y2]

# Call the ODE solver.
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('Ejemplo3_3.dat', 'w') as f:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3], file=f)

# %%
# Plot the solution that was generated

import numpy
import matplotlib.pyplot as plt
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo3_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x1')
ylabel('v')
grid(True)
lw = 1.5

plt.xlim(-10,10)
plt.ylim(-10,10)

plot(x1,y1, 'm', linewidth=lw)
        
title('Phase plot for x1')
savefig('Ejemplo3_3.1.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo3_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x2')
ylabel('v')
grid(True)

lw = 1

plt.xlim(-10,10)
plt.ylim(-10,10)

plot(x2,y2, 'y', linewidth=lw)

title('Phase plot for x2')
savefig('Ejemplo3_3.2.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo3_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x1')
ylabel('x2')
grid(True)

lw = 1
plt.xlim(-10,10)
plt.ylim(-10,10)
plot(x1,x2, 'r', linewidth=lw)

title('Plot of x1 versus x2')
savefig('Ejemplo3_3.3.png', dpi=100)

# %%
import numpy as np
def vectorfield(w, t, p):
    """
    Defines the differential equations for the coupled spring-mass system.

    Arguments:
        w :  vector of the state variables:
                  w = [x1,y1,x2,y2]
        t :  time
        p :  vector of the parameters:
                  p = [m1,m2,k1,k2,L1,L2,b1,b2]
    """
    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2,u1,u2, f1,f2,q1,q2 = p

    # Create f = (x1',y1',x2',y2'):
    f = [y1,
         (-b1 * y1 - k1 * x1 + u1*(x1**3) -k2 * (x1-x2)+ u2*((x1-x2)**3)+ f1*(np.cos(q1*t)) ) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1)+ u2*((x2-x1)**3)+ f2*(np.cos(q2*t))) / m2]
    return f

# %%
# Use ODEINT to solve the differential equations defined by the vector field
from scipy.integrate import odeint

# Parameter values
# Masses:
m1 = 1.0
m2 = 1.0
# Spring constants
k1 = 2/5
k2 = 1.0
# Natural lengths
L1 = 0.0
L2 = 0.0
# Friction coefficients
b1 = 1/10
b2 = 1/5
#Non-linear coefficients
u1=1.0/6.0
u2=1.0/10.0
#Forcing amplitudes
f1=1.0/3.0
f2=1.0/5.0
#Forcing frequencies
q1=1.0
q2=3.0/5.0

# Initial conditions
# x1 and x2 are the initial displacements; y1 and y2 are the initial velocities
x1 = 0.7
y1 = 0.0
x2 = 0.1
y2 = 0.0

# ODE solver parameters
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 200.0
numpoints = 1000

# Create the time samples for the output of the ODE solver.
# I use a large number of points, only because I want to make
# a plot of the solution that looks nice.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
p = [m1, m2, k1, k2, L1, L2, b1, b2,u1,u2,f1,f2,q1,q2]
w0 = [x1, y1, x2, y2]

# Call the ODE solver.
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('Ejemplo4_1.dat', 'w') as f:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3], file=f)

# %%
# Plot the solution that was generated

import matplotlib.pyplot as plt
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo4_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x1')
ylabel('v')
grid(True)

lw = 1
plt.xlim(-1,1)
plt.ylim(-1,1)


plot(x1,y1, 'y', linewidth=lw)

title('Phase plot for x1')
savefig('Ejemplo4_1.1.png', dpi=100)

# %%
# Plot the solution that was generated

import matplotlib.pyplot as plt
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo4_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x2')
ylabel('v')
grid(True)

lw = 1
plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)

plot(x2,y2, 'm', linewidth=lw)

title('Phase plot forx2')
savefig('Ejemplo4_1.2.png', dpi=100)

# %%
# Plot the solution that was generated

import matplotlib.pyplot as plt
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo4_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x1')
grid(True)

lw = 1
plt.xlim(0,140)
plt.ylim(-2,2)
#legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
plot(t,x1, 'b', linewidth=lw)
                                    
title('Plot of x1')
savefig('Ejemplo4_1.3.png', dpi=100)

# %%
# Plot the solution that was generated

import matplotlib.pyplot as plt
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo4_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
ylabel('x2')
grid(True)

lw = 1
plt.xlim(0,140)
plt.ylim(-2,2)

plot(t,x2, 'b', linewidth=lw)

title('Plot of x2')
savefig('Ejemplo4_1.4.png', dpi=100)

# %%
# Plot the solution that was generated

import matplotlib.pyplot as plt
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo4_1.dat', unpack=True,skiprows=550)

figure(1, figsize=(6, 4.5))

xlabel('x1')
ylabel('v')
grid(True)
#hold(True)
lw = 1
plt.xlim(-0.6,0.6)
plt.ylim(-0.6,0.6)


plot(x1,y1, 'b', linewidth=lw)
                                    
#legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Limit cycle for x1')
savefig('Ejemplo4_1.5.png', dpi=100)

# %%
# Plot the solution that was generated

import matplotlib.pyplot as plt
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo4_1.dat', unpack=True,skiprows=550)

figure(1, figsize=(6, 4.5))

xlabel('x2')
ylabel('v')
grid(True)

lw = 1
plt.xlim(-1,1)
plt.ylim(-1,1)

plot(x2,y2, 'r', linewidth=lw)
  
title('Limit cycle for x2')
savefig('Ejemplo4_1.6.png', dpi=100)

# %%
# Plot the solution that was generated

import matplotlib.pyplot as plt
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, xy, x2, y2 = loadtxt('Ejemplo4_1.dat', unpack=True)

figure(1, figsize=(8, 4.5))

xlabel('t')
grid(True)

lw = 1
plt.xlim(110,170)
plt.ylim(-2,2)

plot(t, x1, 'b', linewidth=lw)
plot(t, x2, 'm', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Plot of x1 and x2')
savefig('Ejemplo4_1.7.png', dpi=100)

# %%
# Plot the solution that was generated

import matplotlib.pyplot as plt
from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig, ylabel
from matplotlib.font_manager import FontProperties
% matplotlib inline

t, x1, y1, x2, y2 = loadtxt('Ejemplo4_1.dat', unpack=True, skiprows=550)

figure(1, figsize=(6, 4.5))

xlabel('x1')
ylabel('x2')
grid(True)

lw = 1
plt.xlim(-1,1)
plt.ylim(-1,1)

plot(x1,x2, 'y', linewidth=lw)

title('x1 versus x2')
savefig('Ejemplo4_1.8.png', dpi=100)
