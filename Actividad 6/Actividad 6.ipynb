# %%
def vectorfield(w, t, p):
    """
    Defines the differential equations for the coupled spring-mass system.

    Arguments:
        w :  vector of the state variables:
                  w = [x1,y1,x2,y2]
        t :  time
        p :  vector of the parameters:
                  p = [m1,m2,k1,k2,L1,L2,b1,b2]
    """
    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2 = p

    # Create f = (x1',y1',x2',y2'):
    f = [y1,
         (-b1 * y1 - k1 * (x1 - L1) + k2 * (x2 - x1 - L2)) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1 - L2)) / m2]
    return f

# %%
# Use ODEINT to solve the differential equations defined by the vector field
from scipy.integrate import odeint
import numpy as np
import math

# Parameter values
# Masses:
m1 = 1.0
m2 = 1.0
# Spring constants
k1 = 6.0
k2 = 4.0
# Natural lengths
L1 = 0.0
L2 = 0.0
# Friction coefficients
b1 = 0.0
b2 = 0.0

# Initial conditions
# x1 and x2 are the initial displacements; y1 and y2 are the initial velocities
x1 = 1.0
y1 = 0.0
x2 = 2.0
y2 = 0.0

# ODE solver parameters
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 50.0
numpoints = 250

# Create the time samples for the output of the ODE solver.
# I use a large number of points, only because I want to make
# a plot of the solution that looks nice.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
p = [m1, m2, k1, k2, L1, L2, b1, b2]
w0 = [x1, y1, x2, y2]

# Call the ODE solver.
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('Ejemplo2_1.dat', 'w') as E21:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print(t1, w1[0], w1[1], w1[2], w1[3],np.abs((w1[0]-(np.cos(np.sqrt(2)*t1)))/(np.cos(np.sqrt(2)*t1))), np.abs((w1[2]-(2*np.cos(np.sqrt(2)*t1)))/(2*np.cos(np.sqrt(2)*t1))), file=E21)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline

t, x1, xy, x2, y2, e1, e2 = loadtxt('Ejemplo2_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
grid(True)
lw = 1

plot(t, x1, 'darkred', linewidth=lw)
plot(t, x2, 'navy', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Ejemplo2_1: Gráfica de x1 y x2 contra tiempo.')
savefig('Ejemplo2_1Oscilaciones.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline

t, x1, xy, x2, y2, e1, e2 = loadtxt('Ejemplo2_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x2')
grid(True)
lw = 1

plot(x1, x2, 'darkred', linewidth=lw)

title('Ejemplo2_1: Gráfica de x1 contra x2.')
savefig('Ejemplo2_1Recta.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline

t, x1, xy, x2, y2, e1, e2 = loadtxt('Ejemplo2_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('v')
grid(True)
lw = 1

plot(xy, x1, 'darkred', linewidth=lw)
plot(y2, x2, 'navy', linewidth=lw)

title('Ejemplo2_1: Gráfica de Velocidad contra posición.')
savefig('Ejemplo2_1Velocidad.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline

t, x1, y1, x2, y2, e1, e2 = loadtxt('Ejemplo2_1.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
grid(True)
lw = 1

plot(t, e1, 'r', linewidth=lw)

plot(t, e2, 'b', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Relative Error of x1 and x2')
savefig('error2-1.png', dpi=100)

# %%
def vectorfield(w, t, p):
    """
    Defines the differential equations for the coupled spring-mass system.

    Arguments:
        w :  vector of the state variables:
                  w = [x1,y1,x2,y2]
        t :  time
        p :  vector of the parameters:
                  p = [m1,m2,k1,k2,L1,L2,b1,b2]
    """
    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2 = p

    # Create f = (x1',y1',x2',y2'):
    f = [y1,
         (-b1 * y1 - k1 * (x1 - L1) + k2 * (x2 - x1 - L2)) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1 - L2)) / m2]
    return f

# %%
# Use ODEINT to solve the differential equations defined by the vector field
from scipy.integrate import odeint
import numpy as np
import math

# Parameter values
# Masses:
m1 = 1.0
m2 = 1.0
# Spring constants
k1 = 6.0
k2 = 4.0
# Natural lengths
L1 = 0.0
L2 = 0.0
# Friction coefficients
b1 = 0.0
b2 = 0.0

# Initial conditions
# x1 and x2 are the initial displacements; y1 and y2 are the initial velocities
x1 = -2.0
y1 = 0.0
x2 = 1.0
y2 = 0.0

# ODE solver parameters
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 20.0
numpoints = 250

# Create the time samples for the output of the ODE solver.
# I use a large number of points, only because I want to make
# a plot of the solution that looks nice.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
p = [m1, m2, k1, k2, L1, L2, b1, b2]
w0 = [x1, y1, x2, y2]

# Call the ODE solver.
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('Ejemplo2_2.dat', 'w') as E22:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print(t1, w1[0], w1[1], w1[2], w1[3],np.abs((w1[0]-(-2*(np.cos(2*np.sqrt(3.0)*t1))))/(-2*(np.cos(2*np.sqrt(3.0)*t1)))), np.abs((w1[2]-(np.cos(2*np.sqrt(3.0)*t1)))/(np.cos(2*np.sqrt(3.0)*t1))),file=E22)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline

t, x1, xy, x2, y2, e1, e2 = loadtxt('Ejemplo2_2.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
grid(True)
lw = 1

plot(t, x1, 'r', linewidth=lw)
plot(t, x2, 'b', linewidth=lw)

title('Ejemplo2_2: Gráfica de x1 y x2 vs tiempo.')
savefig('Ejemplo2_2Oscilaciones.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline

t, x1, xy, x2, y2, e1, e2 = loadtxt('Ejemplo2_2.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x2')
grid(True)
lw = 1

plot(x1, x2, 'r', linewidth=lw)

title('Ejemplo2_2: Gráfica de x1 contra x2.')
savefig('Ejemplo2_2Recta.png', dpi=100)

# %%
def vectorfield(w, t, p):
    """
    Defines the differential equations for the coupled spring-mass system.

    Arguments:
        w :  vector of the state variables:
                  w = [x1,y1,x2,y2]
        t :  time
        p :  vector of the parameters:
                  p = [m1,m2,k1,k2,L1,L2,b1,b2]
    """
    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2 = p

    # Create f = (x1',y1',x2',y2'):
    f = [y1,
         (-b1 * y1 - k1 * (x1 - L1) + k2 * (x2 - x1 - L2)) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1 - L2)) / m2]
    return f

# %%
# Use ODEINT to solve the differential equations defined by the vector field
from scipy.integrate import odeint

# Parameter values
# Masses:
m1 = 1.0
m2 = 1.0
# Spring constants
k1 = 0.4
k2 = 1.808
# Natural lengths
L1 = 0.0
L2 = 0.0
# Friction coefficients
b1 = 0.0
b2 = 0.0

# Initial conditions
# x1 and x2 are the initial displacements; y1 and y2 are the initial velocities
x1 = 0.5
y1 = 0.0
x2 = -0.5
y2 = 0.7

# ODE solver parameters
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 50.0
numpoints = 500

# Create the time samples for the output of the ODE solver.
# I use a large number of points, only because I want to make
# a plot of the solution that looks nice.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
p = [m1, m2, k1, k2, L1, L2, b1, b2]
w0 = [x1, y1, x2, y2]

# Call the ODE solver.
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('Ejemplo2_3.dat', 'w') as E23:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print (t1, w1[0], w1[1], w1[2], w1[3], file=E23)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('Ejemplo2_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x1')
grid(True)
lw = 1

plot(x1, xy, 'r', linewidth=lw)

title('Ejemplo2_3: Gráfica de Velocidad contra posición x1.')
savefig('Ejemplo2_3Velocidad1.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('Ejemplo2_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x1')
grid(True)
lw = 1

plot(x2, y2, 'g', linewidth=lw)

title('Ejemplo2_3: Gráfica de Velocidad contra posición x2.')
savefig('Ejemplo2_3Velocidad2.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('Ejemplo2_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
grid(True)
lw = 1

plot(t, x1, 'c', linewidth=lw)

title('Ejemplo2_3: Gráfica de x1 contra tiempo.')
savefig('Ejemplo2_3Oscilaciones1.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('Ejemplo2_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
grid(True)
lw = 1

plot(t, x2, 'b', linewidth=lw)

title('Ejemplo2_3: Gráfica de x2 contra tiempo.')
savefig('Ejemplo2_3Oscilaciones2.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('Ejemplo2_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
grid(True)
lw = 1

plot(t, x1, 'c', linewidth=lw)
plot(t, x2, 'b', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Ejemplo2_3: Gráfica de x1 y x2 contra tiempo.')
savefig('Ejemplo2_3Oscilaciones.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('Ejemplo2_3.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('x2')
grid(True)
lw = 1

plot(x1, x2, 'b', linewidth=lw)

title('Ejemplo2_3: Gráfica de x1 contra x2.')
savefig('Ejemplo2_3Posiciones.png', dpi=100)

# %%
def vectorfield(w, t, p):
    """
    Defines the differential equations for the coupled spring-mass system.

    Arguments:
        w :  vector of the state variables:
                  w = [x1,y1,x2,y2]
        t :  time
        p :  vector of the parameters:
                  p = [m1,m2,k1,k2,L1,L2,b1,b2]
    """
    x1, y1, x2, y2 = w
    m1, m2, k1, k2, L1, L2, b1, b2 = p

    # Create f = (x1',y1',x2',y2'):
    f = [y1,
         (-b1 * y1 - k1 * (x1 - L1) + k2 * (x2 - x1 - L2)) / m1,
         y2,
         (-b2 * y2 - k2 * (x2 - x1 - L2)) / m2]
    return f

# %%
from scipy.integrate import odeint

# Parameter values
# Masses:
m1 = 1.0
m2 = 1.0
# Spring constants
k1 = 0.4
k2 = 1.808
# Natural lengths
L1 = 0.0
L2 = 0.0
# Friction coefficients
b1 = 0.1
b2 = 0.2

# Initial conditions
# x1 and x2 are the initial displacements; y1 and y2 are the initial velocities
#Si quiero escribir fracciones, debo de hacerlo como reales y no como enteros, es decir:
x1 = 1.0
y1 = 1.0/2.0
x2 = 2
y2 = 1.0/2.0

# ODE solver parameters
abserr = 1.0e-8
relerr = 1.0e-6
stoptime = 50.0
numpoints = 1250

# Create the time samples for the output of the ODE solver.
# I use a large number of points, only because I want to make
# a plot of the solution that looks nice.
t = [stoptime * float(i) / (numpoints - 1) for i in range(numpoints)]

# Pack up the parameters and initial conditions:
p = [m1, m2, k1, k2, L1, L2, b1, b2]
w0 = [x1, y1, x2, y2]

# Call the ODE solver.
wsol = odeint(vectorfield, w0, t, args=(p,),
              atol=abserr, rtol=relerr)

with open('Ejemplo2_4.dat', 'w') as f:
    # Print & save the solution.
    for t1, w1 in zip(t, wsol):
        print(t1, w1[0], w1[1], w1[2], w1[3], file=f)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
#Estas bibliotecas van a crearme una imagen en otra pestaña, para hacer que la imagen aparezca dentro del mismo documento que estamos programando agregamos
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('Ejemplo2_4.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
grid(True)
#hold(True)
lw = 1

plot(t, x1, 'b', linewidth=lw)
plot(t, x2, 'y', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Mass Displacements for the\nCoupled Spring-Mass System')
savefig('ejemplo2.4_pt1.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
#Estas bibliotecas van a crearme una imagen en otra pestaña, para hacer que la imagen aparezca dentro del mismo documento que estamos programando agregamos
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('Ejemplo2_4.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
grid(True)
#hold(True)
lw = 1

plot(x1, xy, 'g', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Ejemplo2_4: Gráfica de Velocidad contra posición x1')
savefig('ejemplo2.4_pt2.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
#Estas bibliotecas van a crearme una imagen en otra pestaña, para hacer que la imagen aparezca dentro del mismo documento que estamos programando agregamos
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('Ejemplo2_4.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
grid(True)
#hold(True)
lw = 1

plot(x2, y2, 'm', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Ejemplo2_4: Gráfica de Velocidad contra posición x2')
savefig('ejemplo2.4_pt3.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
#Estas bibliotecas van a crearme una imagen en otra pestaña, para hacer que la imagen aparezca dentro del mismo documento que estamos programando agregamos
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('Ejemplo2_4.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
grid(True)
#hold(True)
lw = 1

plot(t, x1, 'b', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Ejemplo2_4: Gráfica de x1 contra tiempo')
savefig('ejemplo2.4_pt4.png', dpi=100)

# %%
# Plot the solution that was generated

from numpy import loadtxt
from pylab import figure, plot, xlabel, grid, hold, legend, title, savefig
from matplotlib.font_manager import FontProperties
#Estas bibliotecas van a crearme una imagen en otra pestaña, para hacer que la imagen aparezca dentro del mismo documento que estamos programando agregamos
# %matplotlib inline

t, x1, xy, x2, y2 = loadtxt('Ejemplo2_4.dat', unpack=True)

figure(1, figsize=(6, 4.5))

xlabel('t')
grid(True)
#hold(True)
lw = 1

plot(t, x2, '', linewidth=lw)

legend((r'$x_1$', r'$x_2$'), prop=FontProperties(size=16))
title('Ejemplo2_4: Gráfica de x2 contra tiempo')
savefig('ejemplo2.4_pt5.png', dpi=100)
